# %% [markdown]
# ## import library python

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# WARNING:tensorflow:From c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir=r'Coffee Leaves'

filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)                   
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')    
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                             filepaths        labels
# 0    Coffee Leaves\embun_jelaga\1.JPG  embun_jelaga
# 1   Coffee Leaves\embun_jelaga\10.JPG  embun_jelaga
# 2  Coffee Leaves\embun_jelaga\100.JPG  embun_jelaga
# 3  Coffee Leaves\embun_jelaga\101.JPG  embun_jelaga
# 4  Coffee Leaves\embun_jelaga\102.JPG  embun_jelaga
# embun_jelaga              350
# karat_daun                350
# sehat                     350
# tungau_laba_laba_merah    350
# Name: labels, dtype: int64

# %% [markdown]
# ## split df into train_df, test_df and valid_df

# %%
train_split=0.8
test_split=0.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  1120   test_df length:  140   valid_df length:  140

# %% [markdown]
# ## create train, test, valid generators

# %%
height=128
width=128
channels=3
batch_size=64

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(
    rescale=1./255,
    )
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  70   test steps:  2
# Found 1120 validated image filenames belonging to 4 classes.
# Found 140 validated image filenames belonging to 4 classes.
# Found 140 validated image filenames belonging to 4 classes.
# ['embun_jelaga', 'karat_daun', 'sehat', 'tungau_laba_laba_merah']

# %% [markdown]
# ## create function to show some image examples

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %% [markdown]
# ## create the model

# %%
base_model=tf.keras.applications.Xception(include_top=False, weights="imagenet",input_tensor=Input(shape=(128,128,3)))
# Out:
# WARNING:tensorflow:From c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 63, 63, 32)           864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 63, 63, 32)           128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 63, 63, 32)           0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 61, 61, 64)           18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 61, 61, 64)           256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 61, 61, 64)           0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 61, 61, 128)          8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 61, 61, 128)          512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 61, 61, 128)          0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 61, 61, 128)          17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 61, 61, 128)          512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 31, 31, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 31, 31, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 31, 31, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 31, 31, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 31, 31, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 31, 31, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 31, 31, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 31, 31, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 31, 31, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 16, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 16, 16, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 16, 16, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 16, 16, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 728)            186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 728)            0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 8, 8, 728)            2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 8, 8, 728)            0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 8, 8, 728)            0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 8, 8, 728)            536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 8, 8, 728)            2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 8, 8, 728)            0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 8, 8, 728)            536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 8, 8, 728)            2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 8, 8, 728)            0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 8, 8, 728)            536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 8, 8, 728)            2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 8, 8, 728)            0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 8, 8, 728)            0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 8, 8, 728)            536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 8, 8, 728)            2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 8, 8, 728)            0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 8, 8, 728)            536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 8, 8, 728)            2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 8, 8, 728)            0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 8, 8, 728)            536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 8, 8, 728)            2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 8, 8, 728)            0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 8, 8, 728)            0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 8, 8, 728)            536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 8, 8, 728)            2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 8, 8, 728)            0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 8, 8, 728)            536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 8, 8, 728)            2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 8, 8, 728)            0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 8, 8, 728)            536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 8, 8, 728)            2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 8, 8, 728)            0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 8, 8, 728)            0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 8, 8, 728)            536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 8, 8, 728)            2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 8, 8, 728)            0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 8, 8, 728)            536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 8, 8, 728)            2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 8, 8, 728)            0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 8, 8, 728)            536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 8, 8, 728)            2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 8, 8, 728)            0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 8, 8, 728)            0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 8, 8, 728)            536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 8, 8, 728)            2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 8, 8, 728)            0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 8, 8, 728)            536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 8, 8, 728)            2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 8, 8, 728)            0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 8, 8, 728)            536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 8, 8, 728)            2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 8, 8, 728)            0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 8, 8, 728)            0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 8, 8, 728)            536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 8, 8, 728)            2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 8, 8, 728)            0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 8, 8, 728)            536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 8, 8, 728)            2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 8, 8, 728)            0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 8, 8, 728)            536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 8, 8, 728)            2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 8, 8, 728)            0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 8, 8, 728)            0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 8, 8, 728)            536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 8, 8, 728)            2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 8, 8, 728)            0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 8, 8, 728)            536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 8, 8, 728)            2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 8, 8, 728)            0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 8, 8, 728)            536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 8, 8, 728)            2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 8, 8, 728)            0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 8, 8, 728)            0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 8, 8, 728)            536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 8, 8, 728)            2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 8, 8, 728)            0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 8, 8, 728)            536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 8, 8, 728)            2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 8, 8, 728)            0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 8, 8, 728)            536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 8, 8, 728)            2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 8, 8, 728)            0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 8, 8, 728)            0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 8, 8, 728)            536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 8, 8, 728)            2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 8, 8, 728)            0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 8, 8, 1024)           752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 8, 8, 1024)           4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 1024)           745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 4, 4, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 4, 4, 1024)           4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 4, 4, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 4, 4, 1536)           1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 4, 4, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 4, 4, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 4, 4, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 4, 4, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 4, 4, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 20806952 (79.37 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name='Xception'
print("Building model with", base_model)
model = tf.keras.Sequential([
            # Note the input shape is the desired size of the image 128x128 with 3 bytes color
            # This is the first convolution
            base_model,
            tf.keras.layers.Conv2D(filters=32, padding='same', kernel_size=3, activation='relu', strides=1),
            tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
            tf.keras.layers.Dropout(rate=0.5),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(4, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')
# Out:
# Building model with <keras.src.engine.functional.Functional object at 0x00000221BDC8C4D0>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 4, 4, 2048)        20861480
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 32)          589856
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 32)          0
#  D)
#
#  dropout (Dropout)           (None, 2, 2, 32)          0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 21451852 (81.83 MB)
# Trainable params: 590372 (2.25 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
epochs = 100

history=model.fit(x=train_gen, epochs=epochs, validation_data=valid_gen)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 18/18 [==============================] - 210s 11s/step - loss: 1.0717 - accuracy: 0.6446 - val_loss: 0.3236 - val_accuracy: 0.8929
# Epoch 2/100
# 18/18 [==============================] - 219s 12s/step - loss: 0.3277 - accuracy: 0.8866 - val_loss: 0.1066 - val_accuracy: 0.9786
# Epoch 3/100
# 18/18 [==============================] - 222s 12s/step - loss: 0.1667 - accuracy: 0.9420 - val_loss: 0.0565 - val_accuracy: 0.9929
# Epoch 4/100
# 18/18 [==============================] - 219s 13s/step - loss: 0.1055 - accuracy: 0.9607 - val_loss: 0.0427 - val_accuracy: 0.9929
# Epoch 5/100
# 18/18 [==============================] - 220s 12s/step - loss: 0.0778 - accuracy: 0.9768 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch
-04 - val_accuracy: 1.0000
# Epoch 57/100
# 18/18 [==============================] - 142s 8s/step - loss: 0.0119 - accuracy: 0.9973 - val_loss: 3.0359e-05 - val_accuracy: 1.0000
# Epoch 58/100
# 18/18 [==============================] - 138s 8s/step - loss: 0.0191 - accuracy: 0.9946 - val_loss: 5.6683e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 18/18 [==============================] - 139s 8s/step - loss: 0.0235 - accuracy: 0.9893 - val_loss: 1.5934e-04 - val_accuracy: 1.0000
# Epoch 60/100
# 18/18 [==============================] - 143s 8s/step - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 61/100
# 18/18 [==============================] - 166s 9s/step - loss: 0.0092 - accuracy: 0.9964 - val_loss: 7.1967e-05 - val_accuracy: 1.0000
# Epoch 62/100
# 18/18 [==============================] - 211s 12s/step - loss: 0.0065 - accuracy: 0.9964 - val_loss: 9.4678e-06 - val_accuracy: 1.0000
# Epoch 63/100
# 18/18 [==============================] - 211s 12s/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 64/100
# 18/18 [==============================] - 178s 10s/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 7.7111e-06 - val_accuracy: 1.0000
# Epoch 65/100
# 18/18 [==============================] - 143s 8s/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 1.7166e-06 - val_accuracy: 1.0000
# Epoch 66/100
# 18/18 [==============================] - 142s 8s/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 3.1183e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 18/18 [==============================] - 146s 8s/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 5.0601e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 18/18 [==============================] - 144s 8s/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 7.6775e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 18/18 [==============================] - 143s 8s/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 8.8189e-06 - val_accuracy: 1.0000
# Epoch 70/100
# 18/18 [==============================] - 145s 8s/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 6.4964e-06 - val_accuracy: 1.0000
# Epoch 71/100
# 18/18 [==============================] - 141s 8s/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 7.7315e-07 - val_accuracy: 1.0000
# Epoch 72/100
# 18/18 [==============================] - 139s 8s/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 1.0490e-06 - val_accuracy: 1.0000
# Epoch 73/100
# 18/18 [==============================] - 140s 8s/step - loss: 6.1409e-04 - accuracy: 1.0000 - val_loss: 1.2806e-06 - val_accuracy: 1.0000
# Epoch 74/100
# 18/18 [==============================] - 140s 8s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 4.6151e-07 - val_accuracy: 1.0000
# Epoch 75/100
# 18/18 [==============================] - 145s 8s/step - loss: 3.9563e-04 - accuracy: 1.0000 - val_loss: 3.5252e-07 - val_accuracy: 1.0000
# Epoch 76/100
# 18/18 [==============================] - 140s 8s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4097e-07 - val_accuracy: 1.0000
# Epoch 77/100
# 18/18 [==============================] - 140s 8s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.2309e-07 - val_accuracy: 1.0000
# Epoch 78/100
# 18/18 [==============================] - 139s 8s/step - loss: 8.7110e-04 - accuracy: 0.9991 - val_loss: 1.9329e-07 - val_accuracy: 1.0000
# Epoch 79/100
# 18/18 [==============================] - 139s 8s/step - loss: 0.0010 - accuracy: 0.9991 - val_loss: 9.4516e-08 - val_accuracy: 1.0000
# Epoch 80/100
# 18/18 [==============================] - 140s 8s/step - loss: 5.5556e-04 - accuracy: 1.0000 - val_loss: 7.2377e-08 - val_accuracy: 1.0000
# Epoch 81/100
# 18/18 [==============================] - 139s 8s/step - loss: 0.0041 - accuracy: 0.9982 - val_loss: 7.3229e-08 - val_accuracy: 1.0000
# Epoch 82/100
# 18/18 [==============================] - 139s 8s/step - loss: 7.0301e-04 - accuracy: 1.0000 - val_loss: 1.7055e-06 - val_accuracy: 1.0000
# Epoch 83/100
# 18/18 [==============================] - 137s 8s/step - loss: 9.6632e-04 - accuracy: 1.0000 - val_loss: 4.7513e-07 - val_accuracy: 1.0000
# Epoch 84/100
# 18/18 [==============================] - 134s 7s/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 9.3664e-08 - val_accuracy: 1.0000
# Epoch 85/100
# 18/18 [==============================] - 135s 7s/step - loss: 0.0016 - accuracy: 0.9991 - val_loss: 8.0892e-08 - val_accuracy: 1.0000
# Epoch 86/100
# 18/18 [==============================] - 134s 7s/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 3.0172e-06 - val_accuracy: 1.0000
# Epoch 87/100
# 18/18 [==============================] - 135s 7s/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 1.7258e-06 - val_accuracy: 1.0000
# Epoch 88/100
# 18/18 [==============================] - 134s 7s/step - loss: 4.5561e-04 - accuracy: 1.0000 - val_loss: 6.0881e-07 - val_accuracy: 1.0000
# Epoch 89/100
# 18/18 [==============================] - 135s 7s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.6699e-07 - val_accuracy: 1.0000
# Epoch 90/100
# 18/18 [==============================] - 134s 7s/step - loss: 8.5547e-04 - accuracy: 1.0000 - val_loss: 4.9300e-07 - val_accuracy: 1.0000
# Epoch 91/100
# 18/18 [==============================] - 138s 8s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.2782e-07 - val_accuracy: 1.0000
# Epoch 92/100
# 18/18 [==============================] - 420s 24s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.4825e-07 - val_accuracy: 1.0000
# Epoch 93/100
# 18/18 [==============================] - 141s 8s/step - loss: 0.0012 - accuracy: 0.9991 - val_loss: 1.0021e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 18/18 [==============================] - 141s 8s/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 2.0095e-07 - val_accuracy: 1.0000
# Epoch 95/100
# 18/18 [==============================] - 141s 8s/step - loss: 7.9429e-04 - accuracy: 1.0000 - val_loss: 6.3862e-08 - val_accuracy: 1.0000
# Epoch 96/100
# 18/18 [==============================] - 203s 12s/step - loss: 3.1269e-04 - accuracy: 1.0000 - val_loss: 1.2857e-07 - val_accuracy: 1.0000
# Epoch 97/100
# 18/18 [==============================] - 198s 11s/step - loss: 5.7623e-04 - accuracy: 1.0000 - val_loss: 5.1090e-08 - val_accuracy: 1.0000
# Epoch 98/100
# 18/18 [==============================] - 176s 10s/step - loss: 4.2690e-04 - accuracy: 1.0000 - val_loss: 3.3208e-08 - val_accuracy: 1.0000
# Epoch 99/100
# 18/18 [==============================] - 177s 10s/step - loss: 8.8965e-04 - accuracy: 1.0000 - val_loss: 1.3624e-08 - val_accuracy: 1.0000
# Epoch 100/100
# 18/18 [==============================] - 180s 10s/step - loss: 8.2059e-04 - accuracy: 1.0000 - val_loss: 1.4475e-08 - val_accuracy: 1.0000

# %% [markdown]
# ## define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %% [markdown]
# ## define function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %% [markdown]
# ### define function to generate the confusion matrix and classification report

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [markdown]
# ### evaluate model on the test set then save the model

# %%
tr_plot(history,0)
save_dir=r'./'
subject='pest'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 2/2 [==============================] - 21s 10s/step - loss: 8.5149e-09 - accuracy: 1.0000
# accuracy on the test set is 100.00 %
# c:\Users\Nadia Ashari\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### make predictions on test set and generate confusion matrix and classification report

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 2/2 [==============================] - 22s 10s/step
# Classification Report:
# ----------------------
#                          precision    recall  f1-score   support
#
#           embun_jelaga       1.00      1.00      1.00        40
#             karat_daun       1.00      1.00      1.00        23
#                  sehat       1.00      1.00      1.00        38
# tungau_laba_laba_merah       1.00      1.00      1.00        39
#
#               accuracy                           1.00       140
#              macro avg       1.00      1.00      1.00       140
#           weighted avg       1.00      1.00      1.00       140
